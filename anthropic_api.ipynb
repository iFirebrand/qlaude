# %% [markdown]
# # Anthropic API Setup and Usage
#
# This notebook demonstrates how to set up and use the Anthropic API with Claude.

# %% [markdown]
# ## 1. Install Dependencies

# %% [markdown]
# ## 2. Load Environment Variables

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Get the API key
api_key = os.getenv("ANTHROPIC_API_KEY")

if not api_key:
    print("Warning: ANTHROPIC_API_KEY not found in environment variables")
else:
    print("API key loaded successfully")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 import os
# ----> 2 from dotenv import load_dotenv
#       4 # Load environment variables from .env file
#       5 load_dotenv()
#
# ModuleNotFoundError: No module named 'dotenv'

# %% [markdown]
# ## 3. Create API Client

# %%
from anthropic import Anthropic

# Create the Anthropic client
client = Anthropic(api_key=api_key)

print("Anthropic client created successfully")

# %% [markdown]
# ## 4. Make Request

# %%
# Make a request to Claude
message = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    max_tokens=1024,
    messages=[
        {"role": "user", "content": "Hello, Claude! Tell me a brief fun fact about Python."}
    ]
)

# Print the response
print(message.content[0].text)
